# %%
import pandas as pd

file_path = "C:\\Users\\soswo\\OneDrive\\Desktop\\projects\\solar-challenge-week1\\data\\raw\\Kenya.csv"

# Skip the units row which is row 1
df = pd.read_csv(file_path, encoding='ISO-8859-1', skiprows=[1])

# Convert all columns except Timestamp and Comments to numeric (safe conversion)
for col in df.columns:
    if col not in ['Timestamp', 'Comments']:
        df[col] = pd.to_numeric(df[col], errors='coerce')

print("🔍 Summary Statistics:\n")
print(df.describe())

print("\n🧼 Missing Value Report:\n")
missing_counts = df.isna().sum()
print(missing_counts[missing_counts > 0])

print("\n⚠️ Columns with >5% Missing Values:\n")
total_rows = len(df)
null_ratio = (missing_counts / total_rows) * 100
high_null_columns = null_ratio[null_ratio > 5]
print(high_null_columns)
# Out:
# C:\Users\soswo\AppData\Local\Temp\ipykernel_22144\4127320235.py:6: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='ISO-8859-1', skiprows=[1])
# 🔍 Summary Statistics:
#
#        time        dhi_pyr      ghi_pyr_1      ghi_pyr_2  air_temperature  \
# count   0.0  525596.000000  525582.000000  525583.000000    525593.000000
# mean    NaN      86.063378     269.047398     268.371196        18.279863
# std     NaN     127.704617     375.643771     375.299775         3.983100
# min     NaN       0.000000       0.000000       0.000000         8.270000
# 25%     NaN       0.000000       0.000000       0.000000        15.220000
# 50%     NaN       2.440000       2.670000       1.590000        17.290000
# 75%     NaN     132.800000     511.937500     510.760000        21.260000
# max     NaN     747.620000    1647.960000    1654.550000        30.390000
#
#        relative_humidity  barometric_pressure  precipitation     wind_speed  \
# count      525596.000000        525593.000000  525596.000000  525596.000000
# mean           70.503945           811.689363       0.000971       4.385126
# std            18.725167             1.652078       0.017920       1.788280
# min            15.220000           806.620000       0.000000       0.000000
# 25%            56.110000           810.560000       0.000000       3.230000
# 50%            72.710000           811.690000       0.000000       4.460000
# 75%            86.200000           812.830000       0.000000       5.620000
# max           100.000000           817.840000       1.200000      12.170000
#
#        wind_from_direction      gti_clean       gti_soil    gti_monthly  \
# count        525596.000000  525593.000000  525596.000000  525596.000000
# mean            130.170648     253.635093     252.497750     250.071404
# std              48.923671     358.866481     357.093353     353.942700
# min               0.000000       0.000000       0.000000       0.000000
# 25%             110.140000       0.000000       0.000000       0.000000
# 50%             121.160000       2.310000       2.310000       2.320000
# 75%             132.870000     476.170000     474.112500     469.032500
# max             360.000000    1546.450000    1530.240000    1503.850000
#
#        sensor_cleaning  comments
# count    525596.000000       0.0
# mean          0.000584       NaN
# std           0.024161       NaN
# min           0.000000       NaN
# 25%           0.000000       NaN
# 50%           0.000000       NaN
# 75%           0.000000       NaN
# max           1.000000       NaN
#
# 🧼 Missing Value Report:
#
# time                   525599
# dhi_pyr                     3
# ghi_pyr_1                  17
# ghi_pyr_2                  16
# air_temperature             6
# relative_humidity           3
# barometric_pressure         6
# precipitation               3
# wind_speed                  3
# wind_from_direction         3
# gti_clean                   6
# gti_soil                    3
# gti_monthly                 3
# sensor_cleaning             3
# comments               525599
# dtype: int64
#
# ⚠️ Columns with >5% Missing Values:
#
# time        100.0
# comments    100.0
# dtype: float64

# %%
import os
import pandas as pd
import numpy as np
from scipy.stats import zscore

file_path = "C:\\Users\\soswo\\OneDrive\\Desktop\\projects\\solar-challenge-week1\\data\\raw\\Benin.csv"

# Skip the units row which is row 1
df = pd.read_csv(file_path, encoding='ISO-8859-1', skiprows=[1])


# Columns to process
key_columns = ['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']

# Compute Z-scores and filter outliers
z_scores = df[key_columns].apply(zscore)
outliers = (np.abs(z_scores) > 3).any(axis=1)

# Log number of outliers removed
print(f'Removing {outliers.sum()} outlier rows.')

# Drop outliers
df_cleaned = df[~outliers].copy()

# Handle missing values: impute with median
df_cleaned[key_columns] = df_cleaned[key_columns].fillna(df_cleaned[key_columns].median())

# Save to cleaned file
country = 'Benin'  # Replace with your country name
output_path = f'C:\\Users\\soswo\\OneDrive\\Desktop\\projects\\solar-challenge-week1\\data\\processed\\{country}_clean.csv'
os.makedirs('data\\processed', exist_ok=True)
df_cleaned.to_csv(output_path, index=False)

print(f"Cleaned data saved to: {output_path}")
# Out:
# Removing 11428 outlier rows.
# Cleaned data saved to: C:\Users\soswo\OneDrive\Desktop\projects\solar-challenge-week1\data\processed\Benin_clean.csv

# %%
import pandas as pd

file_path = "C:\\Users\\soswo\\OneDrive\\Desktop\\projects\\solar-challenge-week1\\data\\raw\\Liberia.csv"

# Skip the units row which is row 1
df = pd.read_csv(file_path, encoding='ISO-8859-1', skiprows=[1])

# Convert all columns except Timestamp and Comments to numeric (safe conversion)
for col in df.columns:
    if col not in ['Timestamp', 'Comments']:
        df[col] = pd.to_numeric(df[col], errors='coerce')

print("🔍 Summary Statistics:\n")
print(df.describe())

print("\n🧼 Missing Value Report:\n")
missing_counts = df.isna().sum()
print(missing_counts[missing_counts > 0])

print("\n⚠️ Columns with >5% Missing Values:\n")
total_rows = len(df)
null_ratio = (missing_counts / total_rows) * 100
high_null_columns = null_ratio[null_ratio > 5]
print(high_null_columns)
# Out:
# 🔍 Summary Statistics:
#
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      184.116881      93.541927     112.245286     174.466155
# std       280.324709     197.180030     152.385695     266.125860
# min        -6.200000       0.000000       0.000000       0.000000
# 25%        -0.900000       0.000000       0.000000       0.000000
# 50%         2.500000       0.000000       2.100000       3.500000
# 75%       301.300000      33.500000     215.900000     280.500000
# max      1528.000000     982.700000     798.400000    1473.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      180.476757      26.224115      84.027740       0.326666
# std       275.313234       3.209602      12.487662       0.836482
# min         0.000000      19.800000      26.900000       0.000000
# 25%         0.000000      23.800000      76.300000       0.000000
# 50%         3.700000      25.000000      90.100000       0.000000
# 75%       290.600000      28.400000      93.600000       0.000000
# max      1523.000000      37.100000      96.800000      11.600000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        0.684775       0.190451      50.646175       2.032518
# std         1.380444       0.361569      94.916255       4.294414
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.400000       0.200000      26.800000       0.100000
# max        17.600000       3.300000     360.000000      83.400000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean     1010.555752       0.000400       0.004955      30.808278
# std         2.005355       0.019985       0.048772       9.167349
# min      1004.000000       0.000000       0.000000      19.200000
# 25%      1009.000000       0.000000       0.000000      24.200000
# 50%      1011.000000       0.000000       0.000000      26.200000
# 75%      1012.000000       0.000000       0.000000      35.900000
# max      1016.000000       1.000000       5.400000      67.200000
#
#                TModB         GHIrsi  Comments
# count  525600.000000  525600.000000       0.0
# mean       30.363053     181.827157       NaN
# std         9.147089     275.039432       NaN
# min        19.100000       0.000000       NaN
# 25%        24.000000       0.000000       NaN
# 50%        25.500000       2.100000       NaN
# 75%        35.200000     298.100000       NaN
# max        67.200000    1549.700000       NaN
#
# 🧼 Missing Value Report:
#
# Comments    525600
# dtype: int64
#
# ⚠️ Columns with >5% Missing Values:
#
# Comments    100.0
# dtype: float64

# %%
import os
import pandas as pd
import numpy as np
from scipy.stats import zscore

file_path = "C:\\Users\\soswo\\OneDrive\\Desktop\\projects\\solar-challenge-week1\\data\\raw\\Liberia.csv"

# Skip the units row which is row 1
df = pd.read_csv(file_path, encoding='ISO-8859-1', skiprows=[1])


# Columns to process
key_columns = ['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']

# Compute Z-scores and filter outliers
z_scores = df[key_columns].apply(zscore)
outliers = (np.abs(z_scores) > 3).any(axis=1)

# Log number of outliers removed
print(f'Removing {outliers.sum()} outlier rows.')

# Drop outliers
df_cleaned = df[~outliers].copy()

# Handle missing values: impute with median
df_cleaned[key_columns] = df_cleaned[key_columns].fillna(df_cleaned[key_columns].median())

# Save to cleaned file
country = 'Liberia'  # Replace with your country name
output_path = f'C:\\Users\\soswo\\OneDrive\\Desktop\\projects\\solar-challenge-week1\\data\\processed\\{country}_clean.csv'
os.makedirs('data\\processed', exist_ok=True)
df_cleaned.to_csv(output_path, index=False)

print(f"Cleaned data saved to: {output_path}")
# Out:
# Removing 35838 outlier rows.
# Cleaned data saved to: C:\Users\soswo\OneDrive\Desktop\projects\solar-challenge-week1\data\processed\Liberia_clean.csv

# %%
import pandas as pd

file_path = "C:\\Users\\soswo\\OneDrive\\Desktop\\projects\\solar-challenge-week1\\data\\raw\\Kenya.csv"

# Skip the units row which is row 1
df = pd.read_csv(file_path, encoding='ISO-8859-1', skiprows=[1])

# Convert all columns except Timestamp and Comments to numeric (safe conversion)
for col in df.columns:
    if col not in ['Timestamp', 'Comments']:
        df[col] = pd.to_numeric(df[col], errors='coerce')

print("🔍 Summary Statistics:\n")
print(df.describe())

print("\n🧼 Missing Value Report:\n")
missing_counts = df.isna().sum()
print(missing_counts[missing_counts > 0])

print("\n⚠️ Columns with >5% Missing Values:\n")
total_rows = len(df)
null_ratio = (missing_counts / total_rows) * 100
high_null_columns = null_ratio[null_ratio > 5]
print(high_null_columns)
# Out:
# C:\Users\soswo\AppData\Local\Temp\ipykernel_22144\4127320235.py:6: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='ISO-8859-1', skiprows=[1])
# 🔍 Summary Statistics:
#
#        time        dhi_pyr      ghi_pyr_1      ghi_pyr_2  air_temperature  \
# count   0.0  525596.000000  525582.000000  525583.000000    525593.000000
# mean    NaN      86.063378     269.047398     268.371196        18.279863
# std     NaN     127.704617     375.643771     375.299775         3.983100
# min     NaN       0.000000       0.000000       0.000000         8.270000
# 25%     NaN       0.000000       0.000000       0.000000        15.220000
# 50%     NaN       2.440000       2.670000       1.590000        17.290000
# 75%     NaN     132.800000     511.937500     510.760000        21.260000
# max     NaN     747.620000    1647.960000    1654.550000        30.390000
#
#        relative_humidity  barometric_pressure  precipitation     wind_speed  \
# count      525596.000000        525593.000000  525596.000000  525596.000000
# mean           70.503945           811.689363       0.000971       4.385126
# std            18.725167             1.652078       0.017920       1.788280
# min            15.220000           806.620000       0.000000       0.000000
# 25%            56.110000           810.560000       0.000000       3.230000
# 50%            72.710000           811.690000       0.000000       4.460000
# 75%            86.200000           812.830000       0.000000       5.620000
# max           100.000000           817.840000       1.200000      12.170000
#
#        wind_from_direction      gti_clean       gti_soil    gti_monthly  \
# count        525596.000000  525593.000000  525596.000000  525596.000000
# mean            130.170648     253.635093     252.497750     250.071404
# std              48.923671     358.866481     357.093353     353.942700
# min               0.000000       0.000000       0.000000       0.000000
# 25%             110.140000       0.000000       0.000000       0.000000
# 50%             121.160000       2.310000       2.310000       2.320000
# 75%             132.870000     476.170000     474.112500     469.032500
# max             360.000000    1546.450000    1530.240000    1503.850000
#
#        sensor_cleaning  comments
# count    525596.000000       0.0
# mean          0.000584       NaN
# std           0.024161       NaN
# min           0.000000       NaN
# 25%           0.000000       NaN
# 50%           0.000000       NaN
# 75%           0.000000       NaN
# max           1.000000       NaN
#
# 🧼 Missing Value Report:
#
# time                   525599
# dhi_pyr                     3
# ghi_pyr_1                  17
# ghi_pyr_2                  16
# air_temperature             6
# relative_humidity           3
# barometric_pressure         6
# precipitation               3
# wind_speed                  3
# wind_from_direction         3
# gti_clean                   6
# gti_soil                    3
# gti_monthly                 3
# sensor_cleaning             3
# comments               525599
# dtype: int64
#
# ⚠️ Columns with >5% Missing Values:
#
# time        100.0
# comments    100.0
# dtype: float64

# %%
import pandas as pd

file_path = "C:\\Users\\soswo\\OneDrive\\Desktop\\projects\\solar-challenge-week1\\data\\raw\\Benin.csv"

# Skip the units row which is row 1
df = pd.read_csv(file_path, encoding='ISO-8859-1', skiprows=[1])

# Convert all columns except Timestamp and Comments to numeric (safe conversion)
for col in df.columns:
    if col not in ['Timestamp', 'Comments']:
        df[col] = pd.to_numeric(df[col], errors='coerce')

print("🔍 Summary Statistics:\n")
print(df.describe())

print("\n🧼 Missing Value Report:\n")
missing_counts = df.isna().sum()
print(missing_counts[missing_counts > 0])

print("\n⚠️ Columns with >5% Missing Values:\n")
total_rows = len(df)
null_ratio = (missing_counts / total_rows) * 100
high_null_columns = null_ratio[null_ratio > 5]
print(high_null_columns)
# Out:
# 🔍 Summary Statistics:
#
#                  GHI            DNI            DHI           ModA  \
# count  570240.000000  570240.000000  570240.000000  570240.000000
# mean      210.666413     128.993430     113.658299     211.157510
# std       309.162327     235.852047     160.898582     306.040173
# min       -16.400000      -7.000000     -18.700000       0.000000
# 25%        -3.200000      -0.400000      -3.500000       0.000000
# 50%        -0.200000      -0.100000      -0.300000       3.800000
# 75%       382.200000     140.200000     218.700000     369.300000
# max      1457.000000     962.000000     805.000000    1396.000000
#
#                 ModB           Tamb             RH             WS  \
# count  570240.000000  570240.000000  570240.000000  570240.000000
# mean      199.764365      26.522331      67.555609       2.130042
# std       289.250008       4.252923      26.120238       1.316869
# min         0.000000      15.400000       8.500000       0.000000
# 25%         0.000000      23.200000      44.200000       1.200000
# 50%         3.600000      25.600000      77.500000       2.100000
# 75%       352.200000      29.400000      90.600000       3.000000
# max      1367.000000      40.100000      97.300000      14.200000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  570240.000000  570240.000000  570240.000000  570240.000000
# mean        3.002046       0.556876     149.577518      12.167306
# std         1.701105       0.266093      90.466559       7.018884
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.900000       0.400000      66.500000       8.200000
# 50%         2.900000       0.500000     177.000000      12.200000
# 75%         4.200000       0.700000     213.100000      16.200000
# max        20.100000       4.300000     360.000000      95.200000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  570240.000000  570240.000000  570240.000000  570240.000000
# mean      971.432204       0.001080       0.002697      32.628936
# std         2.105169       0.032849       0.039250      11.954939
# min       964.000000       0.000000       0.000000      13.100000
# 25%       970.000000       0.000000       0.000000      23.400000
# 50%       972.000000       0.000000       0.000000      26.700000
# 75%       973.000000       0.000000       0.000000      41.900000
# max       979.000000       1.000000       3.200000      81.300000
#
#                TModB  Comments
# count  570240.000000       0.0
# mean       31.887797       NaN
# std        11.130965       NaN
# min        13.100000       NaN
# 25%        23.400000       NaN
# 50%        26.500000       NaN
# 75%        40.300000       NaN
# max        69.000000       NaN
#
# 🧼 Missing Value Report:
#
# Comments    570240
# dtype: int64
#
# ⚠️ Columns with >5% Missing Values:
#
# Comments    100.0
# dtype: float64
